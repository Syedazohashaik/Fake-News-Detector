# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('Fake1.csv')
true = pd.read_csv('True1.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class']=0
true['class']=1

# %%
data = pd.concat([fake,true], axis = 0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 8783   Responding to criticism, Trump calls on Justic...
# 8741    The Head Of The NRA Just Issued The Dumbest C...
# 5650   Emirates, Etihad, Qatar to let barred passenge...
# 6958   Pence: Trump will focus fast on tax, healthcar...
# 4044    Megyn Kelly Called Trump A ‘Predator’; What N...
# 14430  Iranian Revolutionary Guards commander, anothe...
# 9196      U.S. House passes Puerto Rico debt relief bill
# 6920    Megyn Kelly Caves To Trump, Holds Secret Meet...
# 13715  BAHA! CBS REPORTER ASKS HILLARY Why She’s So U...
# 5138    ‘Fishy’: Trump’s Business Audit Reveals Why H...
#
#                                                     text       subject  \
# 8783   WASHINGTON (Reuters) - U.S. Republican preside...  politicsNews
# 8741   Wayne LaPierre has a way about him that define...          News
# 5650   DUBAI (Reuters) - Emirates [EMIRA.UL], Etihad ...  politicsNews
# 6958   (Reuters) - The Trump administration plans to ...  politicsNews
# 4044   It s Fox News, but that doesn t mean that ever...          News
# 14430  BEIRUT (Reuters) - A commander in Iran s elite...     worldnews
# 9196   WASHINGTON (Reuters) - Following months of int...  politicsNews
# 6920   Donald Trump has spent this election demeaning...          News
# 13715  This is a rare moment of uncomfortable questio...      politics
# 5138   In January, GOP presidential candidate Donald ...          News
#
#                      date  class
# 8783       July 13, 2016       1
# 8741     January 15, 2016      0
# 5650    February 4, 2017       1
# 6958    December 2, 2016       1
# 4044     October 26, 2016      0
# 14430  November 19, 2017       1
# 9196        June 9, 2016       1
# 6920       April 13, 2016      0
# 13715        Jun 10, 2016      0
# 5138       August 8, 2016      0

# %%
data=data.drop(["title","subject","date"], axis = 1)

# %%
data.reset_index(inplace=True)

# %%
import pandas as pd

data = pd.read_csv('Fake1.csv')
data = pd.read_csv('True1.csv')

# %%
print(data.head())        # See first 5 rows
print(data.columns)       # See column names
data.reset_index(drop=True, inplace=True)  # reset index if needed
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
data.reset_index(drop=True, inplace=True)

# %%
print(data.columns)
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
print(data.columns)
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.sample(5)
# Out:
#                                                    title  \
# 19829  Qatar to buy 24 Typhoon jets from UK's BAE Sys...
# 6712   Factbox: Trump to meet tech leaders from Googl...
# 11134  Obama administration seeks to curb methane emi...
# 2637   'No more woe is me': Senator McCain vows quick...
# 1891   Trump says he has 'great heart' for immigrant ...
#
#                                                     text       subject  \
# 19829  DOHA (Reuters) - Qatar s defense minister has ...     worldnews
# 6712   (Reuters) - U.S. President-elect Donald Trump ...  politicsNews
# 11134  WASHINGTON (Reuters) - In its latest move to c...  politicsNews
# 2637   WASHINGTON/PHOENIX, Ariz. (Reuters) - U.S. Sen...  politicsNews
# 1891   WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
#
#                       date
# 19829  September 17, 2017
# 6712    December 14, 2016
# 11134    January 22, 2016
# 2637        July 20, 2017
# 1891    September 5, 2017

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', "", text) 
    text = re.sub(r"\W", " ", text)  
    text = re.sub(r"https?://\S+|www\.\S+", "", text)  
    text = re.sub(r"<.*?>+", "", text)  
    text = re.sub(r"[%s]" % re.escape(string.punctuation), "", text)  
    text = re.sub(r"\n", "", text) 
    text = re.sub(r"\w*\d\w*", "", text)  
    return text

# %%
x=data["text"]
y=data["class"]

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
lr = LogisticRegression()
lr.fit(xv_train,ytrain)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test,ytest)
# Out:
# 0.9858351893095768

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']

# %%
transform_input = vectorizer.transform([news_input])

# %%
import joblib

# Load vectorizer and model once
vectorizer = joblib.load("vectorizer.jb")
model = joblib.load("lr_model.jb")

news_input = "some news text here"

transform_input = vectorizer.transform([news_input])
prediction = model.predict(transform_input)

print(prediction)
# Out:
# [0]

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\HP\Documents\fake_news_detector\venv\Scripts\python.exe
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]

# %%
import rich
print("Rich module is installed and working!")
# Out:
# Rich module is installed and working!
